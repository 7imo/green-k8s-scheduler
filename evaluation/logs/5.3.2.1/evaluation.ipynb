# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create data
x=["17:00:00", "17:04:00", "17:08:00", "17:12:00", "17:16:00", "17:20:00", "17:24:00", "17:28:00", "17:32:00", "17:36:00"]
consumption=[158.3,171.04,179.19,2143.29,2162.82,0,2766.85,2805.69,2820.49,2941.14]
excess=[2844.1,2831.36,2823.21,425.41,405.88,2435.3,0,0,0,0]

# Basic stacked area chart.
plt.figure(figsize=(9,3))
plt.stackplot(x,consumption, excess, labels=['Consumption','Renewable Excess'], colors = ['lightgrey', 'mediumseagreen'])
plt.plot([], [], '--', color="firebrick", label="Pod Deployment")
plt.legend(loc='upper left')
plt.ylim(0, 5000)
plt.xlabel("Time")
plt.ylabel("Watt")
plt.title("172.20.47.54")
xposition = ["17:08:00", "17:20:00", "17:32:00", "17:36:00"]
for xc in xposition:
    plt.axvline(x=xc, color='firebrick', linestyle='--')

plt.show()

# %%
# Create data
x=["17:00:00", "17:04:00", "17:08:00", "17:12:00", "17:16:00", "17:20:00", "17:24:00", "17:28:00", "17:32:00", "17:36:00"]
consumption=[138.69,2134.62,2131.4,2177.1,3129.76,3099.32,3088.5,3141.62,4908.85,5242.81]
excess=[2407.81,411.88,415.1,305.5,0,312.98,323.8,270.68,0,0]

# Basic stacked area chart.
plt.figure(figsize=(9,3))
plt.stackplot(x,consumption, excess, labels=['Consumption','Renewable Excess'], colors = ['lightgrey', 'mediumseagreen'])
plt.plot([], [], '--', color="firebrick", label="Pod Deployment")
plt.legend(loc='upper left')
plt.ylim(0, 5000)
plt.xlabel("Time")
plt.ylabel("Watt")
plt.title("172.20.56.113")
xposition = ["17:00:00", "17:12:00", "17:28:00"]
for xc in xposition:
    plt.axvline(x=xc, color='firebrick', linestyle='--')

plt.show()

# %%
# Create data
x=["17:00:00", "17:04:00", "17:08:00", "17:12:00", "17:16:00", "17:20:00", "17:24:00", "17:28:00", "17:32:00", "17:36:00"]
consumption=[153.26,135.76,2154.47,2133.22,2129.54,2520.98,2568.81,3170.04,3067,3034.6]
excess=[1088.44,1105.94,0,0,0,730.82,682.99,81.76,0,0]

# Basic stacked area chart.
plt.figure(figsize=(9,3))
plt.stackplot(x,consumption, excess, labels=['Consumption','Renewable Excess'], colors = ['lightgrey', 'mediumseagreen'])
plt.plot([], [], '--', color="firebrick", label="Pod Deployment")
plt.legend(loc='upper left')
plt.ylim(0, 5000)
plt.xlabel("Time")
plt.ylabel("Watt")
plt.title("172.20.33.14")
xposition = ["17:04:00", "17:16:00", "17:24:00"]
for xc in xposition:
    plt.axvline(x=xc, color='firebrick', linestyle='--')

plt.show()
